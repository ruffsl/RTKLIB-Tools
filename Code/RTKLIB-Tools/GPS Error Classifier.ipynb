# %%
from matplotlib import pyplot, mpl
from pandas.lib import Timestamp
import pandas as pd
import scipy as sp
import numpy as np
import pylab as pl
import geopy as gp
import sklearn as skp
from plot_utils import *
from file_utils import *

# %%
indir = '/home/ruffin/Documents/Data/in/'
outdir = '/home/ruffin/Documents/Data/out/'
indir = checkDir(indir,'r')
outdir = checkDir(outdir,'r')
posFile = findFile(outdir,'.pos')
print(posFile)
# Out:
# Checking directory: /home/ruffin/Documents/Data/in/
# Checking directory: /home/ruffin/Documents/Data/out/
# CMU Center static part.pos

# %%
df = pd.read_csv(posFile, skiprows=23, delim_whitespace=True, parse_dates=[[0, 1]])
df.head(10)
# Out:
#                       %_GPST  latitude(deg)  longitude(deg)  height(m)  Q  ns  sdn(m)  \
# 0        2013-06-04 23:09:00      40.442636      -79.943065   258.6469  2  11  0.0208
# 1 2013-06-04 23:09:00.200000      40.442636      -79.943064   258.9419  2  11  0.0382
# 2 2013-06-04 23:09:00.400000      40.442636      -79.943064   258.9461  2  11  0.0380
# 3 2013-06-04 23:09:00.600000      40.442636      -79.943064   258.9477  2  11  0.0378
# 4 2013-06-04 23:09:00.800000      40.442636      -79.943064   258.9534  2  11  0.0376
# 5        2013-06-04 23:09:01      40.442636      -79.943064   258.9547  2  11  0.0375
# 6 2013-06-04 23:09:01.200000      40.442636      -79.943064   258.9594  2  11  0.0373
# 7 2013-06-04 23:09:01.400000      40.442636      -79.943064   258.9595  2  11  0.0371
# 8 2013-06-04 23:09:01.600000      40.442636      -79.943064   258.9645  2  11  0.0369
# 9 2013-06-04 23:09:01.800000      40.442636      -79.943064   258.9656  2  11  0.0367
#
#    sde(m)  sdu(m)  sdne(m)  sdeu(m)  sdun(m)  age(s)  ratio
# 0  0.0156  0.0446  -0.0062   0.0030  -0.0178     0.0    1.7
# 1  0.0269  0.0641  -0.0098   0.0178  -0.0233   -29.8    1.7
# 2  0.0267  0.0639  -0.0097   0.0177  -0.0233   -29.6    1.7
# 3  0.0266  0.0636  -0.0097   0.0175  -0.0232   -29.4    1.7
# 4  0.0265  0.0634  -0.0097   0.0174  -0.0231   -29.2    1.6
# 5  0.0264  0.0632  -0.0096   0.0173  -0.0230   -29.0    1.6
# 6  0.0262  0.0629  -0.0096   0.0171  -0.0229   -28.8    1.6
# 7  0.0261  0.0627  -0.0096   0.0170  -0.0229   -28.6    1.5
# 8  0.0260  0.0625  -0.0095   0.0169  -0.0228   -28.4    1.4
# 9  0.0259  0.0622  -0.0095   0.0167  -0.0227   -28.2    1.4

# %%
df.describe()
# Out:
#        latitude(deg)  longitude(deg)    height(m)     Q           ns       sdn(m)  \
# count    1201.000000     1201.000000  1201.000000  1201  1201.000000  1201.000000
# mean       40.442636      -79.943065   258.784984     2    10.912573     0.029446
# std         0.000003        0.000003     0.124023     0     0.282578     0.002951
# min        40.442634      -79.943067   258.477300     2    10.000000     0.020100
# 25%        40.442636      -79.943066   258.705100     2    11.000000     0.027100
# 50%        40.442636      -79.943065   258.742900     2    11.000000     0.029200
# 75%        40.442636      -79.943063   258.855700     2    11.000000     0.031500
# max        40.442638      -79.943062   259.209300     2    11.000000     0.038300
#
#             sde(m)       sdu(m)      sdne(m)      sdeu(m)      sdun(m)       age(s)  \
# count  1201.000000  1201.000000  1201.000000  1201.000000  1201.000000  1201.000000
# mean      0.020993     0.053511    -0.008447     0.011607    -0.020412   -14.887594
# std       0.001864     0.003408     0.001598     0.002538     0.001943     8.670728
# min       0.015200     0.042700    -0.016400     0.003000    -0.038000   -29.800000
# 25%       0.019600     0.050900    -0.009100     0.009900    -0.021000   -22.400000
# 50%       0.020800     0.053100    -0.008600     0.011600    -0.020000   -14.800000
# 75%       0.022300     0.055800    -0.008100     0.013400    -0.019300    -7.400000
# max       0.027800     0.072600     0.001300     0.028300    -0.013500     0.000000
#
#              ratio
# count  1201.000000
# mean      1.153289
# std       0.190896
# min       1.000000
# 25%       1.000000
# 50%       1.100000
# 75%       1.200000
# max       1.800000

# %%
# Center CMU
reference = point.Point(40.442635758, -79.943065017, 258.7)
# Office Window
#reference = point.Point(40.443874, -79.945517, 272)
# Under Bridge Center
#reference = point.Point(40.441369, -79.949325, 254)

df['sd(m)'] = np.sqrt(df['sdn(m)']**2+df['sde(m)']**2+df['sdu(m)']**2+df['sdne(m)']**2+df['sdeu(m)']**2+df['sdun(m)']**2)
df['dist(m)'] = 0.0
df['distn(m)'] = 0.0
df['diste(m)'] = 0.0
df['distu(m)'] = 0.0
d = distance.distance
for i in df.index :
    j = point.Point(df['latitude(deg)'][i],df['longitude(deg)'][i])
    k = point.Point(reference.latitude,df['longitude(deg)'][i])
    l = point.Point(df['latitude(deg)'][i],reference.longitude)
    
    lat1 = math.radians(reference.latitude)
    lon1 = math.radians(reference.longitude)
    lat2 = math.radians(df['latitude(deg)'][i])
    lon2 = math.radians(df['longitude(deg)'][i])
    
    dLon = lon2 - lon1;
    y = math.sin(dLon) * math.cos(lat2);
    x = math.cos(lat1)*math.sin(lat2) - math.sin(lat1)*math.cos(lat2)*math.cos(dLon);
    brng = math.atan2(y, x);
    north = math.cos(brng)
    east = math.sin(brng)
    
    j = d(reference, j).meters
    k = d(reference, k).meters*np.sign(east)
    l = d(reference, l).meters*np.sign(north)
    m = (df['height(m)'][i] - reference.altitude)
    q = np.core.sqrt(j**2+m**2)
    
    df['dist(m)'][i] = q
    df['distn(m)'][i] = k
    df['diste(m)'][i] = l
    df['distu(m)'][i] = m
df.describe()
# Out:
#        latitude(deg)  longitude(deg)    height(m)     Q           ns       sdn(m)  \
# count    1201.000000     1201.000000  1201.000000  1201  1201.000000  1201.000000
# mean       40.442636      -79.943065   258.784984     2    10.912573     0.029446
# std         0.000003        0.000003     0.124023     0     0.282578     0.002951
# min        40.442634      -79.943067   258.477300     2    10.000000     0.020100
# 25%        40.442636      -79.943066   258.705100     2    11.000000     0.027100
# 50%        40.442636      -79.943065   258.742900     2    11.000000     0.029200
# 75%        40.442636      -79.943063   258.855700     2    11.000000     0.031500
# max        40.442638      -79.943062   259.209300     2    11.000000     0.038300
#
#             sde(m)       sdu(m)      sdne(m)      sdeu(m)      sdun(m)       age(s)  \
# count  1201.000000  1201.000000  1201.000000  1201.000000  1201.000000  1201.000000
# mean      0.020993     0.053511    -0.008447     0.011607    -0.020412   -14.887594
# std       0.001864     0.003408     0.001598     0.002538     0.001943     8.670728
# min       0.015200     0.042700    -0.016400     0.003000    -0.038000   -29.800000
# 25%       0.019600     0.050900    -0.009100     0.009900    -0.021000   -22.400000
# 50%       0.020800     0.053100    -0.008600     0.011600    -0.020000   -14.800000
# 75%       0.022300     0.055800    -0.008100     0.013400    -0.019300    -7.400000
# max       0.027800     0.072600     0.001300     0.028300    -0.013500     0.000000
#
#              ratio        sd(m)      dist(m)     distn(m)     diste(m)     distu(m)
# count  1201.000000  1201.000000  1201.000000  1201.000000  1201.000000  1201.000000
# mean      1.153289     0.069304     0.171547     0.029771     0.019854     0.084984
# std       0.190896     0.005229     0.101323     0.103847     0.071017     0.124023
# min       1.000000     0.053578     0.035604    -0.150930    -0.151685    -0.222700
# 25%       1.000000     0.065322     0.095400    -0.074150    -0.023652     0.005100
# 50%       1.100000     0.068743     0.155398     0.025282     0.021209     0.042900
# 75%       1.200000     0.072830     0.219527     0.129465     0.042085     0.155700
# max       1.800000     0.100122     0.538001     0.231867     0.238743     0.509300

# %%
plt.figure()
df[['sd(m)','sdn(m)','sde(m)','sdu(m)']].plot()
plt.legend(loc='upper right')

# %%
plt.figure()
df[['distn(m)','diste(m)','distu(m)','dist(m)']].plot()
plt.legend(loc='upper right')

# %%
dff = df[df['dist(m)'] <= .1]
print('Generating Fig 8')
fig8 = pyplot.figure(figsize=(18,12), dpi=80)
ax = fig8.add_subplot(1,1,1)
dff.hist(column=['sdn(m)','sde(m)','sdu(m)'], bins=50,ax=ax)
# Out:
# Generating Fig 8
# array([[<matplotlib.axes.AxesSubplot object at 0x7f0fc5bb3950>,
#         <matplotlib.axes.AxesSubplot object at 0x7f0fc59b32d0>],
#        [<matplotlib.axes.AxesSubplot object at 0x7f0fc5902c90>,
#         <matplotlib.axes.AxesSubplot object at 0x7f0fc58c7bd0>]], dtype=object)

# %%
df.describe
# Out:
# <bound method DataFrame.describe of <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1201 entries, 0 to 1200
# Data columns:
# %_GPST            1201  non-null values
# latitude(deg)     1201  non-null values
# longitude(deg)    1201  non-null values
# height(m)         1201  non-null values
# Q                 1201  non-null values
# ns                1201  non-null values
# sdn(m)            1201  non-null values
# sde(m)            1201  non-null values
# sdu(m)            1201  non-null values
# sdne(m)           1201  non-null values
# sdeu(m)           1201  non-null values
# sdun(m)           1201  non-null values
# age(s)            1201  non-null values
# ratio             1201  non-null values
# sd(m)             1201  non-null values
# dist(m)           1201  non-null values
# distn(m)          1201  non-null values
# diste(m)          1201  non-null values
# distu(m)          1201  non-null values
# dtypes: datetime64[ns](1), float64(16), int64(2)>

# %%
import numpy as np
import pylab as pl
from sklearn import svm, datasets
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve, auc
random_state = np.random.RandomState(0)

# %%
#X = np.asarray(df[['Q','ns','sdn(m)','sde(m)','sdu(m)','ratio']])
dff = df
X = ['Q','ns','sd(m)','ratio']
y = 'y'
#n_samples, n_features = dff.shape
#half = int(n_samples / 2)
dff[y] = np.less(np.asarray(dff['dist(m)']),0.10)

dff_train = dff[::2]
dff_test = dff[1::2]

# %%
# Run classifier
classifier = svm.SVC(kernel='rbf', probability=True)
classifier.fit(dff_train[X], dff_train[y])
probas_ = classifier.predict_proba(dff_test[X])
dff_test['probas_'] = probas_[:, 1]
y_ = classifier.predict(dff_test[X])
dff_test['y_'] = y_.values

# %%
# Compute ROC curve and area the curve
fpr, tpr, thresholds = roc_curve(dff_test['y'], dff_test['probas_'])
roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)

# Plot ROC curve
pl.clf()
pl.figure(figsize=(18,12), dpi=80)
pl.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
pl.plot([0, 1], [0, 1], 'k--')
pl.xlim([0.0, 1.0])
pl.ylim([0.0, 1.0])
pl.xlabel('False Positive Rate')
pl.ylabel('True Positive Rate')
pl.title('Receiver operating characteristic example')
pl.legend(loc="lower right")
pl.show()
# Out:
# Area under the ROC curve : 0.736527

# %%
#from sklearn.decomposition import PCA
#pca = PCA(n_components=2)
#pca.fit(X)
#X_reduced = pca.transform(X)
#print("Reduced dataset shape:", X_reduced.shape)

#import pylab as pl
#pl.figure(figsize=(18,12), dpi=80)
#pl.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y)

#print("Meaning of the 2 components:")
#for component in pca.components_:
#    print(" + ".join("%.3f x %s" % (value, name))
#        for value, name in zip(component, dff.columns))

# %%
from sklearn.metrics import classification_report
target_names = ['Outside', 'Inside']
print(classification_report(dff_test['y'], dff_test['y_'], target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     Outside       0.73      1.00      0.85       439
#      Inside       0.00      0.00      0.00       161
#
# avg / total       0.54      0.73      0.62       600

# %%
from sklearn.metrics import confusion_matrix
# Compute confusion matrix
cm = confusion_matrix(dff_test['y'], dff_test['y_'])

print(cm)

# Show confusion matrix
pl.matshow(cm)
pl.title('Confusion matrix')
pl.colorbar()
pl.show()
# Out:
# [[439   0]
#  [161   0]]

# %%
dff_test['TFPN'] = ''
for i in dff_test.index:
    yp = dff_test['y'][i]
    y_ = dff_test['y_'][i]
    s = ''
    if ~ (yp ^ y_):
        s += 'T'
        if y:
            s += 'P'
        else:
            s += 'N'
    else:
        s += 'F'
        if y:
            s += 'P'
        else:
            s += 'N'
    
    dff_test['TFPN'][i] = s

# %%
dff_test.to_csv('/home/ruffin/Desktop/test.csv')

# %%
dff_test_TP = dff_test[dff_test['TFPN'].str.contains("TP")]
dff_test_TN = dff_test[dff_test['TFPN'].str.contains("TN")]
dff_test_FP = dff_test[dff_test['TFPN'].str.contains("FP")]
dff_test_FN = dff_test[dff_test['TFPN'].str.contains("FN")]

print('Generating Fig')
fig1 = pyplot.figure(figsize=(18,18), dpi=200)
fig1.suptitle('Labeled Solutions', fontsize=14, fontweight='bold')
#ax = fig1.add_subplot(111)
ax = fig1.add_subplot(111,aspect='equal')
p = ax.scatter(dff_test_TP['distn(m)'],dff_test_TP['diste(m)'], label= 'TP', alpha=1, c='green')
p = ax.scatter(dff_test_TN['distn(m)'],dff_test_TN['diste(m)'], label= 'TN', alpha=1, c='blue')
p = ax.scatter(dff_test_FP['distn(m)'],dff_test_FP['diste(m)'], label= 'FP', alpha=1, c='red')
p = ax.scatter(dff_test_FN['distn(m)'],dff_test_FN['diste(m)'], label= 'FN', alpha=1, c='orange')
pl.legend(loc="lower right")
#xlim(distnminlim, distnmaxlim)
#ylim(disteminlim, distemaxlim)
ax.set_xlabel('East (meters)')
ax.set_ylabel('North (meters)')
ax.grid(True)
# Out:
# Generating Fig
